# %%
import torch

print(torch.__version__)
print("CUDA available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
# Out:
# 2.11.0+cu128
# CUDA available: True
# GPU: Tesla T4

# %%
# !git clone https://github.com/YakshithK/DreamGrid.git
# %cd DreamGrid
# Out:
# Cloning into 'DreamGrid'...
# remote: Enumerating objects: 74, done.
# remote: Counting objects: 100% (74/74), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 74 (delta 19), reused 65 (delta 10), pack-reused 0 (from 0)
# Receiving objects: 100% (74/74), 606.58 KiB | 2.41 MiB/s, done.
# Resolving deltas: 100% (19/19), done.
# /content/DreamGrid

# %%
import sys
sys.path.append("/content/DreamGrid")

# %%
# !python -m data.generate_transitions
# Out:
# Generating data/train_transitions.npz: 100% 50000/50000 [00:16<00:00, 3114.17it/s]
# Generating data/val_transitions.npz: 100% 5000/5000 [00:01<00:00, 3750.34it/s]
# Generating data/test_transitions.npz: 100% 5000/5000 [00:01<00:00, 3752.91it/s]

# %%
# !python -m training.train_pixel

# %%
# !python -m eval.visualize_pixel_preds

# %%
from IPython.display import Image

Image("outputs/pixel_predictions.png")

# %%
# !python -m training.train_autoencoder \
  --epochs 3 \
  --batch_size 128 \
  --latent_dim 64
# Out:
# Using device: cuda
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/content/DreamGrid/training/train_autoencoder.py", line 136, in <module>
#     main()
#   File "/content/DreamGrid/training/train_autoencoder.py", line 98, in main
#     train_loader = DataLoader(train_dataset, batch_size=args.batch_size, shuffle=True, num_workers=2)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py", line 394, in __init__
#     sampler = RandomSampler(dataset, generator=generator)  # type: ignore[arg-type]
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/sampler.py", line 148, in __init__
#     if not isinstance(self.num_samples, int) or self.num_samples <= 0:
# ...
