# %%
import torch

print(torch.__version__)
print("CUDA available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
# Out:
# 2.11.0+cu128
# CUDA available: True
# GPU: Tesla T4

# %%
# !git clone https://github.com/YakshithK/DreamGrid.git
# %cd DreamGrid
# Out:
# Cloning into 'DreamGrid'...
# remote: Enumerating objects: 44, done.
# remote: Counting objects: 100% (44/44), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 44 (delta 9), reused 41 (delta 6), pack-reused 0 (from 0)
# Receiving objects: 100% (44/44), 9.10 KiB | 3.03 MiB/s, done.
# Resolving deltas: 100% (9/9), done.
# /content/DreamGrid

# %%
import sys
sys.path.append("/content/DreamGrid")

# %%
# !python -m data.generate_transitions
# Out:
# Generating data/train_transitions.npz: 100% 50000/50000 [00:16<00:00, 2961.19it/s]
# Generating data/val_transitions.npz: 100% 5000/5000 [00:01<00:00, 3330.29it/s]
# Generating data/test_transitions.npz: 100% 5000/5000 [00:01<00:00, 3444.24it/s]

# %%
# !python -m training.train_pixel
# Out:
# Using device: cuda
# Epoch 1: 100% 391/391 [00:42<00:00,  9.27it/s]
# Epoch 1: train_l1=0.102701, val_l1=0.000253
# Saved best model to checkpoints/pixel_model.pt
# Epoch 2: 100% 391/391 [00:44<00:00,  8.75it/s]
# Epoch 2: train_l1=0.020131, val_l1=0.000106
# Saved best model to checkpoints/pixel_model.pt
# Epoch 3: 100% 391/391 [00:49<00:00,  7.93it/s]
# Epoch 3: train_l1=0.012076, val_l1=0.000125
# Epoch 4: 100% 391/391 [00:48<00:00,  8.01it/s]
# Epoch 4: train_l1=0.010662, val_l1=0.000076
# Saved best model to checkpoints/pixel_model.pt
# Epoch 5: 100% 391/391 [00:49<00:00,  7.91it/s]
# Epoch 5: train_l1=0.009194, val_l1=0.000071
# Saved best model to checkpoints/pixel_model.pt
# Epoch 6: 100% 391/391 [00:48<00:00,  7.99it/s]
# Epoch 6: train_l1=0.008331, val_l1=0.000064
# Saved best model to checkpoints/pixel_model.pt
# Epoch 7: 100% 391/391 [00:49<00:00,  7.97it/s]
# Epoch 7: train_l1=0.007825, val_l1=0.000065
# Epoch 8: 100% 391/391 [00:48<00:00,  8.00it/s]
# Epoch 8: train_l1=0.006562, val_l1=0.000046
# Saved best model to checkpoints/pixel_model.pt
# Epoch 9: 100% 391/391 [00:48<00:00,  7.99it/s]
# Epoch 9: train_l1=0.004541, val_l1=0.000040
# Saved best model to checkpoints/pixel_model.pt
# Epoch 10: 100% 391/391 [00:48<00:00,  8.00it/s]
# Epoch 10: train_l1=0.004130, val_l1=0.000029
# Saved best model to checkpoints/pixel_model.pt

# %%
# !python -m eval.visualize_pixel_preds
# Out:
# Saved visualization to outputs/pixel_predictions.png

# %%
from IPython.display import Image

Image("outputs/pixel_predictions.png")
