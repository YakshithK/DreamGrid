# %%
import torch

print(torch.__version__)
print("CUDA available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))

# %%
# !git clone https://github.com/YakshithK/DreamGrid.git
# %cd DreamGrid

# %%
import sys
sys.path.append("/content/DreamGrid")

# %%
# !python -m scripts.generate_transitions

# %%
# !python -m training.baselines.train_pixel

# %%
# !python -m eval.visualizations.visualize_pixel_preds

# %%
from IPython.display import Image

Image("outputs/pixel_predictions.png")

# %%
# !python -m training.baselines.train_autoencoder

# %%
# !python -m eval.visualizations.visualize_reconstructions

from IPython.display import Image

Image("outputs/reconstructions.png")

# %%
# !python -m eval.diagnostics.probe_latent_position
