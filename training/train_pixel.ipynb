# %%
import torch

print(torch.__version__)
print("CUDA available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
# Out:
# 2.11.0+cu128
# CUDA available: True
# GPU: Tesla T4

# %%
# !git clone https://github.com/YakshithK/DreamGrid.git
# %cd DreamGrid
# Out:
# Cloning into 'DreamGrid'...
# remote: Enumerating objects: 44, done.
# remote: Counting objects: 100% (44/44), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 44 (delta 9), reused 41 (delta 6), pack-reused 0 (from 0)
# Receiving objects: 100% (44/44), 9.10 KiB | 3.03 MiB/s, done.
# Resolving deltas: 100% (9/9), done.
# /content/DreamGrid

# %%
import sys
sys.path.append("/content/DreamGrid")

# %%
# !python -m data.generate_transitions
# Out:
# Generating data/train_transitions.npz: 100% 50000/50000 [00:16<00:00, 3046.93it/s]
# Generating data/val_transitions.npz: 100% 5000/5000 [00:02<00:00, 2072.73it/s]
# Generating data/test_transitions.npz: 100% 5000/5000 [00:01<00:00, 3561.92it/s]

# %%
# !python -m training.train_pixel
# Out:
# Using device: cuda
# Epoch 1: 100% 391/391 [00:42<00:00,  9.17it/s]
# Epoch 1: train_l1=0.057284, val_l1=735.786068
# Saved best model to checkpoints/pixel_model.pt
# Epoch 2: 100% 391/391 [00:43<00:00,  8.95it/s]
# Epoch 2: train_l1=0.024936, val_l1=459.307093
# Saved best model to checkpoints/pixel_model.pt
# Epoch 3: 100% 391/391 [00:48<00:00,  8.12it/s]
# Epoch 3: train_l1=0.021377, val_l1=387.586449
# Saved best model to checkpoints/pixel_model.pt
# Epoch 4: 100% 391/391 [00:48<00:00,  8.02it/s]
# Epoch 4: train_l1=0.017804, val_l1=215.380426
# Saved best model to checkpoints/pixel_model.pt
# Epoch 5: 100% 391/391 [00:48<00:00,  8.01it/s]
# Epoch 5: train_l1=0.009411, val_l1=147.584826
# Saved best model to checkpoints/pixel_model.pt
# Epoch 6: 100% 391/391 [00:48<00:00,  8.10it/s]
# Epoch 6: train_l1=0.009704, val_l1=137.362295
# Saved best model to checkpoints/pixel_model.pt
# Epoch 7: 100% 391/391 [00:48<00:00,  8.09it/s]
# Epoch 7: train_l1=0.007778, val_l1=139.892438
# Epoch 8: 100% 391/391 [00:48<00:00,  8.03it/s]
# Epoch 8: train_l1=0.008142, val_l1=147.965009
# Epoch 9: 100% 391/391 [00:48<00:00,  8.11it/s]
# Epoch 9: train_l1=0.007632, val_l1=118.651850
# Saved best model to checkpoints/pixel_model.pt
# Epoch 10: 100% 391/391 [00:48<00:00,  8.07it/s]
# Epoch 10: train_l1=0.007952, val_l1=107.451735
# Saved best model to checkpoints/pixel_model.pt

# %%
# !python -m eval.visualize_pixel_preds
# Out:
# Saved visualization to outputs/pixel_predictions.png

# %%
from IPython.display import Image

Image("outputs/pixel_predictions.png")
